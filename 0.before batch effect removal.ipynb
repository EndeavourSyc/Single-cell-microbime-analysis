# %%
import pandas as pd
from functools import reduce
import scanpy as sc
adata_ct = sc.read_h5ad("./aggr_ct.h5ad")
import matplotlib.pyplot as plt

# %%
adata_ct
# Out:
# AnnData object with n_obs × n_vars = 501268 × 23370
#     obs: 'Run', 'n_genes_by_counts', 'total_counts', 'total_counts_mt', 'pct_counts_mt', 'n_genes', 'NCBI', 'leiden', 'Barcode', 'Barcode-Run', 'Tissue', 'Gender', 'Smoking', 'Diagnosis', 'Stage', 'TNM Staging', 'Mutations', 'CellType'
#     var: 'gene_ids', 'feature_types', 'mt'
#     uns: 'CellType_colors', 'NCBI_colors', 'dendrogram_CellType', 'rank_genes_groups'
#     obsm: 'X_pca', 'X_umap'
#     varm: 'PCs'

# %%
sc.pl.scatter(adata_ct, x='total_counts', y='pct_counts_mt')
sc.pl.scatter(adata_ct, x='total_counts', y='n_genes_by_counts')

# %%
sc.tl.pca(adata_ct, svd_solver='arpack')

# %%
sc.pp.neighbors(adata_ct, n_neighbors=60, n_pcs=7)
# Out:
# D:\Anaconda\envs\sc10\lib\site-packages\umap\distances.py:1063: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# D:\Anaconda\envs\sc10\lib\site-packages\umap\distances.py:1071: NumbaDeprecationWarning: The 'nopython' keyword argument was not supplied to the 'numba.jit' decorator. The implicit default value for this argument is currently False, but it will be changed to True in Numba 0.59.0. See https://numba.readthedocs.io/en/stable/reference/deprecation.html#deprecation-of-object-mode-fall-back-behaviour-when-using-jit for details.
#   @numba.jit()
# ...

# %%
sc.tl.umap(adata_ct)
